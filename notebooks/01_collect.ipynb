# %% [markdown]
# Ces données (production par type d’énergie) représentent la quantité d’électricité disponible et utilisée au Maroc chaque année.
# la production totale ≈ consommation totale (car tout ce qui est produit est consommé dans le pays).

# %%
import pandas as pd

# Charger fichier : Production d'électricité à partir des sources fossiles (pétrole, gaz, charbon),
# (% du total) - Morocco

df = pd.read_csv("../data/raw/API_EG.ELC.FOSL.ZS_DS2_fr_csv_v2_49108.csv", skiprows=4)
# Voir les colonnes existantes
print(df.columns)
 # Voir la liste des pays
print(df['Country Name'].unique())
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        '2023', '2024', 'Unnamed: 69'],
#       dtype='object')
# ['Aruba' nan 'Afghanistan' 'Angola' 'Albanie' 'Andorre' 'Le monde arabe'
#  'Émirats arabes unis' 'Argentine' 'Arménie' 'Samoa américaines'
#  'Antigua-et-Barbuda' 'Australie' 'Autriche' 'Azerbaïdjan' 'Burundi'
#  'Belgique' 'Bénin' 'Burkina Faso' 'Bangladesh' 'Bulgarie' 'Bahreïn'
# ...

# %%
import pandas as pd

# Charger fichier : Production d’électricité à partir de sources d’énergie renouvelables,
#  hors énergie hydroélectrique (kWh) - Morocco

df = pd.read_csv("../data/raw/API_EG.ELC.RNWX.KH_DS2_fr_csv_v2_48972.csv", skiprows=4)
# Voir les colonnes existantes
print(df.columns)
 # Voir la liste des pays
print(df['Country Name'].unique())
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        '2023', '2024', 'Unnamed: 69'],
#       dtype='object')
# ['Aruba' nan 'Afghanistan' 'Angola' 'Albanie' 'Andorre' 'Le monde arabe'
#  'Émirats arabes unis' 'Argentine' 'Arménie' 'Samoa américaines'
#  'Antigua-et-Barbuda' 'Australie' 'Autriche' 'Azerbaïdjan' 'Burundi'
#  'Belgique' 'Bénin' 'Burkina Faso' 'Bangladesh' 'Bulgarie' 'Bahreïn'
# ...

# %%
import pandas as pd

# Charger fichier : Production d’électricité à partir de sources pétrolières (% du total)

df = pd.read_csv("../data/raw/API_EG.ELC.PETR.ZS_DS2_fr_csv_v2_77024.csv", skiprows=4)
# Voir les colonnes existantes
print(df.columns)
 # Voir la liste des pays
print(df['Country Name'].unique())
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        '2023', '2024', 'Unnamed: 69'],
#       dtype='object')
# ['Aruba' nan 'Afghanistan' 'Angola' 'Albanie' 'Andorre' 'Le monde arabe'
#  'Émirats arabes unis' 'Argentine' 'Arménie' 'Samoa américaines'
#  'Antigua-et-Barbuda' 'Australie' 'Autriche' 'Azerbaïdjan' 'Burundi'
#  'Belgique' 'Bénin' 'Burkina Faso' 'Bangladesh' 'Bulgarie' 'Bahreïn'
# ...

# %%
import pandas as pd

# Charger fichier : Production d’électricité à partir de sources pétrolières (% du total)

df = pd.read_csv("../data/raw/observed-timeseries-of-a.csv", skiprows=4)
# Voir les colonnes existantes
print(df.columns)
# Out:
# Index(['1904', '17.26', '17.05'], dtype='object')
